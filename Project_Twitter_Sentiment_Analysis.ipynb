# %% [markdown]
# # Twitter Sentiment Analysis
# #### The aim of the project is to classify the tweets that are floated on twitter as negative, positive or neutral.
# #### In this Project two datasets are taken, one is the training data that contains the text of the tweet and its calssified sentiment whereas the other dataset contains testing data which only includes the tweets whose sentiment we need to predict.
# #### The project of analyzing tweets comes under the domain of "Pattern Classification", which is defined as the process of discovering/exploring useful patterns in large set of data. Natural Language Processing is used in extracting significant patterns and features from large set of data.
# #### After the feature extraction is done, the classification algorithms from the Sklearn library are applied and accuracy score for each was calculated. Following are the algorithms that were applied :
# #### 1) Support Vector Machine (SVM)
# #### 2) Random Forest Classifier
# #### 3) Multinomial Naive Bayes Classifier
# #### 4) Decision Tree Classifier

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Preparing Training Dataset
# #### Importing Training Dataset

# %%
df_train=pd.read_csv("training_twitter_x_y_train.csv")

# %%
print(df_train.shape)
df_train.head()
# Out:
# (10980, 12)
#              tweet_id airline_sentiment    airline airline_sentiment_gold  \
# 0  567900433542488064          negative  Southwest                    NaN
# 1  569989168903819264          positive  Southwest                    NaN
# 2  568089179520954368          positive     United                    NaN
# 3  568928195581513728          negative  Southwest                    NaN
# 4  568594180014014464          negative     United                    NaN
#
#             name negativereason_gold  retweet_count  \
# 0  ColeyGirouard                 NaN              0
# 1  WalterFaddoul                 NaN              0
# 2      LocalKyle                 NaN              0
# 3    amccarthy19                 NaN              0
# 4        J_Okayy                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @SouthwestAir I am scheduled for the morning, ...         NaN
# 1  @SouthwestAir seeing your workers time in and ...         NaN
# 2  @united Flew ORD to Miami and back and  had gr...         NaN
# 3     @SouthwestAir @dultch97 that's horse radish 😤🐴         NaN
# 4  @united so our flight into ORD was delayed bec...         NaN
#
#                tweet_created              tweet_location  \
# 0  2015-02-17 20:16:29 -0800             Washington D.C.
# 1  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2  2015-02-18 08:46:29 -0800                    Illinois
# 3  2015-02-20 16:20:26 -0800                         NaN
# 4  2015-02-19 18:13:11 -0800                         NaN
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Central Time (US & Canada)
# 2  Central Time (US & Canada)
# 3      Atlantic Time (Canada)
# 4  Eastern Time (US & Canada)

# %%
df_train=df_train[['text','airline_sentiment']]
df_train.head()
# Out:
#                                                 text airline_sentiment
# 0  @SouthwestAir I am scheduled for the morning, ...          negative
# 1  @SouthwestAir seeing your workers time in and ...          positive
# 2  @united Flew ORD to Miami and back and  had gr...          positive
# 3     @SouthwestAir @dultch97 that's horse radish 😤🐴          negative
# 4  @united so our flight into ORD was delayed bec...          negative

# %%
training_documents=df_train.values

# %% [markdown]
# ### Spliiting the text into words using NLTK

# %%
from nltk.tokenize import word_tokenize

tweets_train=[]
for i in range(len(training_documents)):
    tweets_train.append([word_tokenize(training_documents[i][0]),training_documents[i][1]])

# %%
import random
random.shuffle(tweets_train)
tweets_train[0:3]
# Out:
# [[['@',
#    'USAirways',
#    'flight',
#    '#',
#    '654',
#    'sitting',
#    'at',
#    'JFK',
#    'with',
#    'delays',
#    'for',
#    '3-1/2',
#    'hrs',
#    '!',
#    'No',
#    'employees',
#    'to',
#    'load',
#    'bags',
#    '?',
#    '#',
#    'terrible'],
#   'negative'],
#  [['@',
#    'SouthwestAir',
#    'only',
#    '1',
#    'guest',
#    'needs',
#    'to',
#    'change',
#    'a',
#    'flight',
#    'on',
#    'a',
#    'reservation',
#    'of',
#    '2',
#    '.',
#    'How',
#    'can',
#    'I',
#    'do',
#    'it',
#    '?',
#    'I',
#    'NEED',
#    'this',
#    'to',
#    'happen',
#    '.',
#    'Say',
#    'it',
#    'can',
#    '...',
#    'Please',
#    'help',
#    '!'],
#   'neutral'],
#  [['@',
#    'USAirways',
#    'Are',
#    'you',
#    'not',
#    'even',
#    'going',
#    'to',
#    'acknowledge',
#    'that',
#    'you',
#    'bumped',
#    'me',
#    'from',
#    'a',
#    'flight',
#    '(',
#    'NOT',
#    'BECAUSE',
#    'OF',
#    'WEATHER',
#    'I',
#    'AM',
#    'IN',
#    'ARIZONA',
#    ')'],
#   'negative']]

# %% [markdown]
# ### Part Of Speech using NLTK

# %%
from nltk.corpus import wordnet

# %%
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %% [markdown]
# ### Identifying StopWords Along with punctuations

# %%
import string
from nltk.corpus import stopwords
stops=set(stopwords.words("english"))
punctuations=list(string.punctuation)
stops.update(punctuations)
stops, string.punctuation
# Out:
# ({'!',
#   '"',
#   '#',
#   '$',
#   '%',
#   '&',
#   "'",
#   '(',
#   ')',
#   '*',
#   '+',
#   ',',
#   '-',
#   '.',
#   '/',
#   ':',
#   ';',
#   '<',
#   '=',
#   '>',
#   '?',
#   '@',
#   '[',
#   '\\',
#   ']',
#   '^',
#   '_',
#   '`',
#   'a',
#   'about',
#   'above',
#   'after',
#   'again',
#   'against',
#   'ain',
#   'all',
#   'am',
#   'an',
#   'and',
#   'any',
#   'are',
#   'aren',
#   "aren't",
#   'as',
#   'at',
#   'be',
#   'because',
#   'been',
#   'before',
#   'being',
#   'below',
#   'between',
#   'both',
#   'but',
#   'by',
#   'can',
#   'couldn',
#   "couldn't",
#   'd',
#   'did',
#   'didn',
#   "didn't",
#   'do',
#   'does',
#   'doesn',
#   "doesn't",
#   'doing',
#   'don',
#   "don't",
#   'down',
#   'during',
#   'each',
#   'few',
#   'for',
#   'from',
#   'further',
#   'had',
#   'hadn',
#   "hadn't",
#   'has',
#   'hasn',
#   "hasn't",
#   'have',
#   'haven',
#   "haven't",
#   'having',
#   'he',
#   'her',
#   'here',
#   'hers',
#   'herself',
#   'him',
#   'himself',
#   'his',
#   'how',
#   'i',
#   'if',
#   'in',
#   'into',
#   'is',
#   'isn',
#   "isn't",
#   'it',
#   "it's",
#   'its',
#   'itself',
#   'just',
#   'll',
#   'm',
#   'ma',
#   'me',
#   'mightn',
#   "mightn't",
#   'more',
#   'most',
#   'mustn',
#   "mustn't",
#   'my',
#   'myself',
#   'needn',
#   "needn't",
#   'no',
#   'nor',
#   'not',
#   'now',
#   'o',
#   'of',
#   'off',
#   'on',
#   'once',
#   'only',
#   'or',
#   'other',
#   'our',
#   'ours',
#   'ourselves',
#   'out',
#   'over',
#   'own',
#   're',
#   's',
#   'same',
#   'shan',
#   "shan't",
#   'she',
#   "she's",
#   'should',
#   "should've",
#   'shouldn',
#   "shouldn't",
#   'so',
#   'some',
#   'such',
#   't',
#   'than',
#   'that',
#   "that'll",
#   'the',
#   'their',
#   'theirs',
#   'them',
#   'themselves',
#   'then',
#   'there',
#   'these',
#   'they',
#   'this',
#   'those',
#   'through',
#   'to',
#   'too',
#   'under',
#   'until',
#   'up',
#   've',
#   'very',
#   'was',
#   'wasn',
#   "wasn't",
#   'we',
#   'were',
#   'weren',
#   "weren't",
#   'what',
#   'when',
#   'where',
#   'which',
#   'while',
#   'who',
#   'whom',
#   'why',
#   'will',
#   'with',
#   'won',
#   "won't",
#   'wouldn',
#   "wouldn't",
#   'y',
#   'you',
#   "you'd",
#   "you'll",
#   "you're",
#   "you've",
#   'your',
#   'yours',
#   'yourself',
#   'yourselves',
#   '{',
#   '|',
#   '}',
#   '~'},
#  '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~')

# %% [markdown]
# ### Cleaning the Words using WordNetLemmatizer available in NLTK

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
lemmatizer=WordNetLemmatizer()

# %%
def clean_tweets(words):
    output_words=[]
    for w in words:
        if w.isalpha():
            if w.lower() not in stops:
                pos=pos_tag([w])
                clean_word=lemmatizer.lemmatize(w,pos=get_simple_pos(pos[0][1]))
                output_words.append(clean_word.lower())
    return output_words

# %%
for i in range(len(tweets_train)):
    tweets_train[i]=(clean_tweets(tweets_train[i][0]),tweets_train[i][1])

# %%
y_train=[]
tweets=[]
for tweet,sentiment in tweets_train:
    tweets.append(" ".join(tweet))
    y_train.append(sentiment)

# %% [markdown]
# ### Using Count Vectorizer to get the X Train Features

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vec=CountVectorizer(max_features=2000)
x_train_features=count_vec.fit_transform(tweets)

# %% [markdown]
# ### Preparing Testing Dataset

# %%
df_test=pd.read_csv("test_twitter_x_test.csv")

# %%
df_test.head()
# Out:
#              tweet_id     airline airline_sentiment_gold          name  \
# 0  569682010270101504    American                    NaN      zsalim03
# 1  569608307184242688    American                    NaN      sa_craig
# 2  567879304593408001   Southwest                    NaN  DanaChristos
# 3  569757651539660801  US Airways                    NaN      rossj987
# 4  569900705852608513    American                    NaN    tranpham18
#
#   negativereason_gold  retweet_count  \
# 0                 NaN              0
# 1                 NaN              0
# 2                 NaN              1
# 3                 NaN              0
# 4                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @AmericanAir In car gng to DFW. Pulled over 1h...         NaN
# 1  @AmericanAir after all, the plane didn’t land ...         NaN
# 2  @SouthwestAir can't believe how many paying cu...         NaN
# 3  @USAirways I can legitimately say that I would...         NaN
# 4  @AmericanAir still no response from AA. great ...         NaN
#
#                tweet_created       tweet_location               user_timezone
# 0  2015-02-22 18:15:50 -0800                Texas  Central Time (US & Canada)
# 1  2015-02-22 13:22:57 -0800  College Station, TX  Central Time (US & Canada)
# 2  2015-02-17 18:52:31 -0800                   CT  Eastern Time (US & Canada)
# 3  2015-02-22 23:16:24 -0800     Washington, D.C.  Eastern Time (US & Canada)
# 4  2015-02-23 08:44:51 -0800        New York City  Eastern Time (US & Canada)

# %%
testing_documents=np.array(df_test['text'])

# %%
tweets_test=[]
for t in testing_documents:
    t=clean_tweets(word_tokenize(t))
    tweets_test.append(" ".join(t))

# %%
x_test_features=count_vec.transform(tweets_test)

# %% [markdown]
# ### Splitting Training Dataset in order to find Accuracy Score

# %%
from sklearn.model_selection import train_test_split
x_train_tweets,x_test_tweets,y_train_tweets,y_test_tweets=train_test_split(x_train_features,y_train,train_size=0.8,
                                                                           test_size=0.2,random_state=0)

# %% [markdown]
# ### Applying SkLearn Classifiers
# ### SVM (Support Vector Machine)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
svc=SVC()
svc.fit(x_train_tweets,y_train_tweets)
y_test_pred=svc.predict(x_test_tweets)
print("Classification Report:")
print(classification_report(y_test_tweets,y_test_pred))
print("Confusion Matrix: ")
print(confusion_matrix(y_test_tweets,y_test_pred))
print("Accuracy Score: ")
print(accuracy_score(y_test_tweets,y_test_pred)*100,"%",sep=" ")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.92      0.86      1399
#      neutral       0.64      0.49      0.56       441
#     positive       0.75      0.56      0.64       356
#
#     accuracy                           0.78      2196
#    macro avg       0.73      0.66      0.69      2196
# weighted avg       0.77      0.78      0.77      2196
#
# Confusion Matrix:
# [[1292   76   31]
#  [ 188  217   36]
#  [ 112   44  200]]
# Accuracy Score:
# 77.82331511839709 %

# %%
svc.fit(x_train_features,y_train)
y_pred_svc=svc.predict(x_test_features)

# %%
df=pd.DataFrame(y_pred_svc)
df.to_csv('predictions_tweets_svm.csv',index=False,header=False)

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
rfc=RandomForestClassifier()
rfc.fit(x_train_tweets,y_train_tweets)
y_test_pred=rfc.predict(x_test_tweets)
print("Classification Report:")
print(classification_report(y_test_tweets,y_test_pred))
print("Confusion Matrix: ")
print(confusion_matrix(y_test_tweets,y_test_pred))
print("Accuracy Score: ")
print(accuracy_score(y_test_tweets,y_test_pred)*100,"%",sep=" ")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.89      0.86      1399
#      neutral       0.59      0.51      0.55       441
#     positive       0.70      0.61      0.65       356
#
#     accuracy                           0.77      2196
#    macro avg       0.70      0.67      0.68      2196
# weighted avg       0.76      0.77      0.76      2196
#
# Confusion Matrix:
# [[1241  111   47]
#  [ 168  227   46]
#  [  93   47  216]]
# Accuracy Score:
# 76.68488160291439 %

# %%
rfc.fit(x_train_features,y_train)
y_pred_rfc=rfc.predict(x_test_features)

# %%
df=pd.DataFrame(y_pred_rfc)
df.to_csv('predictions_tweets_rfc.csv',index=False,header=False)

# %% [markdown]
# ### Multinomial Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
mnv=MultinomialNB(alpha=1)
mnv.fit(x_train_tweets,y_train_tweets)
y_test_pred=mnv.predict(x_test_tweets)
print("Classification Report:")
print(classification_report(y_test_tweets,y_test_pred))
print("Confusion Matrix: ")
print(confusion_matrix(y_test_tweets,y_test_pred))
print("Accuracy Score: ")
print(accuracy_score(y_test_tweets,y_test_pred)*100,"%",sep=" ")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.87      0.86      1399
#      neutral       0.57      0.53      0.55       441
#     positive       0.69      0.69      0.69       356
#
#     accuracy                           0.77      2196
#    macro avg       0.70      0.70      0.70      2196
# weighted avg       0.77      0.77      0.77      2196
#
# Confusion Matrix:
# [[1212  129   58]
#  [ 156  234   51]
#  [  66   45  245]]
# Accuracy Score:
# 77.00364298724955 %

# %%
mnv.fit(x_train_features,y_train)
y_pred_mnv=mnv.predict(x_test_features)

# %%
df=pd.DataFrame(y_pred_mnv)
df.to_csv('Predictions_tweets_mnv.csv',index=False,header=False)

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn import tree
dt = tree.DecisionTreeClassifier()
dt.fit(x_train_tweets,y_train_tweets)
y_test_pred=dt.predict(x_test_tweets)
print("Classification Report:")
print(classification_report(y_test_tweets,y_test_pred))
print("Confusion Matrix: ")
print(confusion_matrix(y_test_tweets,y_test_pred))
print("Accuracy Score: ")
print(accuracy_score(y_test_tweets,y_test_pred)*100,"%",sep=" ")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.78      0.79      1399
#      neutral       0.46      0.50      0.48       441
#     positive       0.54      0.55      0.54       356
#
#     accuracy                           0.69      2196
#    macro avg       0.60      0.61      0.61      2196
# weighted avg       0.69      0.69      0.69      2196
#
# Confusion Matrix:
# [[1093  195  111]
#  [ 164  222   55]
#  [  95   66  195]]
# Accuracy Score:
# 68.76138433515483 %

# %%
dt.fit(x_train_features,y_train)
y_pred_dt=dt.predict(x_test_features)

# %%
df=pd.DataFrame(y_pred_dt)
df.to_csv('Predictions_tweets_dt.csv',index=False,header=False)

# %% [markdown]
# ### SVM predicts the result with the best accuracy score.
# ### Below are the predicted sentiments according to the SVM Classifier

# %%
import csv
i=0
v=open("Predictions_tweets_svm.csv")
r = csv.reader(v)
for item in r:
    item.insert(0,tweets_test[i])
    i+=1
    print(item)
# Out:
# ['americanair car gng dfw pulled ago icy road aa since ca reach arpt wat', 'negative']
# ['americanair plane land identical bad condition grk accord metars', 'negative']
# ['southwestair ca believe many pay customer left high dry reason flight cancelled flightlations monday bdl wow', 'negative']
# ['usairways legitimately say would rather driven cross country flown us airways', 'negative']
# ['americanair still response aa great job guy', 'positive']
# ['united developer fly tmrw morn min layover earlier flight layover move', 'negative']
# ['usairways hello anyone', 'negative']
# ['usairways husainhaqqani husain u shld protest well one ur party member rehman malik delayed pia flight hour', 'negative']
# ['usairways likely flightaware say plane still durango depart', 'negative']
# ['americanair even give option hold say line busy plz try late flightr', 'negative']
# ['united announcement pre boarding address mobility disability require travel lot stuff preboard', 'negative']
# ['usairways really embarrass ask complimentary detailed http amp argue', 'negative']
# ['southwestair passport time trip could still fly photo id thingsishouldknow ifeeldumb', 'negative']
# ['americanair delayed bag friend lisa pafe get bag day costa rica issue update system', 'negative']
# ['southwestair see travel compete unused fund expiration date hidden fine print never saw', 'negative']
# ['usairways awesome doors close minute flight leaf minute plane get wth', 'negative']
# ['united flew united last month experience awesome', 'negative']
# ['jetblue accepting apple pay mobile enterprise http', 'neutral']
# ['united cab ride dfw love get bag reimburse', 'negative']
# ['jetblue ill call morning upset right', 'negative']
# ['southwestair aarp appreciate tweet back unexpected', 'positive']
# ['united status flight', 'neutral']
# ['americanair literally stop allow people wait line customer service incredible bad customer service', 'negative']
# ['americanair really want get home tonight preferably please stop delay plane americanairlines', 'negative']
# ['usairways hold reservation desk hour help', 'negative']
# ['jetblue flight flight plane visible snack crumb seat upon boarding', 'negative']
# ['americanair nothing mother nature like poor commutation', 'negative']
# ['usairways would rather plane get expose nasty contagious virus work wth get flight change late flightr date', 'negative']
# ['jetblue hi guy general enquires email address please thanks david', 'neutral']
# ['united finally arrive bogota good long flight', 'negative']
# ['americanair oh seem undone seat selection mce want cx card select free seat', 'negative']
# ['jetblue like marie harf go iraiq find isis spread good offer resume service isis order find job marieharf', 'negative']
# ['usairways hold minute get receipt know guy busy think time high staff', 'negative']
# ['united baggage track system worthless tell nothing bag much less plan get', 'negative']
# ['usairways hd since flgt dca msy cancelled flightled still try get hold', 'negative']
# ['usairways never fly u airway', 'negative']
# ['united even mention rude customer service u business owner mortify employee act', 'negative']
# ['southwestair understand delay stuck plane longer flight unacceptable', 'negative']
# ['americanair stuck miami one bad customer experience ever sure let everyone know time', 'negative']
# ['usairways yes say bag deliver local number say open asked main cust service get hung', 'negative']
# ['virginamerica momma make', 'neutral']
# ['jetblue bad postpone trip ca accommodate guest like southwestair neveragain', 'negative']
# ['americanair u r online cancelled flight cs amp wait time min amp put call amp hungupnohelp', 'negative']
# ['usairways thank', 'positive']
# ['americanair lie lie lie worst travel experience life day clothes vaca lostluggage unprofessional pit mia', 'negative']
# ['jetblue save day expedia lose costumer jetblue makingthingseasy feelbetter', 'negative']
# ['jetblue trading customer experience short term sad previous loyal customer http', 'negative']
# ['united hold flight slc den', 'negative']
# ['http robert amp americanair', 'neutral']
# ['united hi book flight yesterday receive email confirmation number today get error active flight segment', 'negative']
# ['usairways do', 'neutral']
# ['americanair cancelled flightled flight notify rebook phone ca get agent epic fail', 'negative']
# ['americanair plz ky sit plane hour want leave', 'negative']
# ['southwestair bag make greenville tonight forgiven highhopes', 'negative']
# ['southwestair anyone answer phone morning hold minute counting', 'negative']
# ['southwestair prove cuz southwest people even know behind schedule', 'negative']
# ['americanair actually online indicates seat available premium cost allow seat selection time purchase', 'negative']
# ['virginamerica find u flt lax sooner midnight monday would great customer service', 'negative']
# ['united social listen capability awful reply context mention', 'negative']
# ['united congratulation united fail sky gate plane full people wait weather get bad ca leave', 'negative']
# ['americanair still flight ive allll day boarding wait catering', 'negative']
# ['southwestair go delayed chicago offer flight never intend fly', 'negative']
# ['usairways board wait take hopefully', 'negative']
# ['americanair oh nothing issue already resolve air', 'negative']
# ['southwestair thanks get u paradise safely http', 'positive']
# ['americanair thanks', 'positive']
# ['jetblue thanks anyways southwestair back awesome rate amp amaze customer service nomoreaggravation', 'positive']
# ['americanair bad airline entire world flew nightmare knew would', 'negative']
# ['southwestair iphone app adds passbook support airlines travel http', 'neutral']
# ['americanair take one rep different gate rude ask assistance thanks though', 'negative']
# ['united cheertymedad buy tix day flight ca transfer tix flawed security logic flawed customer service', 'negative']
# ['united ua flight currently stuck portland miss ride hour delay getmartyhome', 'negative']
# ['southwestair boooo like airline http', 'negative']
# ['usairways thank website crash', 'positive']
# ['united bag mexico go build house amp suitcase never get flight cle w need', 'negative']
# ['jetblue mom baggage lose fly fort today colombian employee treat u badly need help please', 'negative']
# ['americanair provide u alternative flight hour late flightr ruin trip cancelled flightled angry problem ruin', 'negative']
# ['usairways never fly guy customer service awful', 'negative']
# ['americanair r u serious delay americanairlines ohio dallas miss connect flight http', 'negative']
# ['jetblue thought thing sent', 'neutral']
# ['southwestair wonder reason customer service busy hold past day many hour answer help plz', 'negative']
# ['southwestair flight leave dc today flight cancelled flightled hold hour', 'negative']
# ['united yes lot terrible customer service newark despite raise complaint ignore hence tweet', 'negative']
# ['united stun bag hartford ord ground crew hour move bag yard', 'negative']
# ['usairways bad airline ever travel', 'negative']
# ['southwestair pick winner destinationdragons flightr maybeijustlost whyyounoloveme', 'neutral']
# ['usairways new slogan want arrive time pick u', 'negative']
# ['southwestair please last ticket best friend destinationdragons http', 'neutral']
# ['usairways corybronze inconvenience people freak nut guy two kids strand airport fail', 'negative']
# ['southwestair thank kind response acknowledgement apology go long way southwestrocks', 'positive']
# ['americanair set schedule try keep aaalwayslate flight', 'negative']
# ['americanair dmed name', 'neutral']
# ['united love told would issue refund could get u way hurricane deny', 'negative']
# ['americanair would even consider continue point program receive perk continued bad customer service senseless', 'negative']
# ['southwestair hey yea get thru everything good well day voucher go appreciate', 'positive']
# ['really jetblue fleet fleek http', 'neutral']
# ['southwestair ca dm without follow', 'neutral']
# ['jetblue type plane flt bos rsw', 'negative']
# ['united certainly', 'neutral']
# ['united also ran water refuse service costumerservice legit jk', 'negative']
# ['usairways yes february bad weather happens every winter guy business sense forecast loss', 'negative']
# ['southwestair dm sent thank', 'positive']
# ['usairways mobile app horrible needs major overhaul', 'negative']
# ['southwestair rebook flight board bham', 'neutral']
# ['usairways flight fro orf phl', 'neutral']
# ['southwestair thanks great service staff let change flight time free pvd sky always swa', 'positive']
# ['jetblue well find way get puerto rico tomorrow morning besides charge u three time cash originally paid', 'negative']
# ['americanair hi flight dfw cancelled flightled tonight called left number call back please help', 'negative']
# ['americanair pathetic service', 'negative']
# ['united late flight tire understandably edgy try catch flight chipper def rude', 'negative']
# ['americanair going pathetic online work phone want give seat assignment', 'negative']
# ['virginamerica seat even open laptop paid extra seat', 'negative']
# ['southwestair way get entry las vegas event see imaginedragons perform destinationdragons', 'neutral']
# ['southwestair thank someone finally answer able change flight cancelled flighted bc ice thank response', 'positive']
# ['americanair could get u flight minute funeral start strand dallas luggage day', 'negative']
# ['united', 'neutral']
# ['virginamerica await return phone call would prefer use online option', 'negative']
# ['united ca american airline suppose http', 'negative']
# ['united follow please airline beautifull', 'neutral']
# ['southwestair guy must swamp even take corporate travel long time get everything work end', 'negative']
# ['united addition first flight delayed hour arrive destination hr late flight', 'negative']
# ['united need well airline', 'negative']
# ['americanair try speak agent whole day cancelled flightled flight', 'negative']
# ['jetblue request selfie somewhere rocky milehighselfieclub http', 'neutral']
# ['americanair way', 'neutral']
# ['virginamerica inflight team make experience amaze', 'positive']
# ['americanair post response facebook everyone see people appalled lack concern', 'negative']
# ['southwestair flight nashville today kid airline fly frustrate', 'negative']
# ['united engine problem mechanic try fix problem safety first well change plane', 'negative']
# ['southwestair gf lose promise ring give flight sfo gt sna infinity silver band ring please help', 'negative']
# ['americanair hello question many balloon think take life one plane', 'negative']
# ['united true gate agent cause helpful thanks make miss connection http', 'negative']
# ['jetblue guess wait another hr hope rate go amp reasonable fingers cross cutting close travel date', 'negative']
# ['americanair offer automate call back option agent available call amp sit hold onholdfordays', 'negative']
# ['usairways first class service us today flight attendant catch name top notch', 'negative']
# ['usairways customer service horrible', 'negative']
# ['united campilley hahaha american company would say great sarcasm', 'negative']
# ['americanair please something boarding dca many delay bus plane tarmac despite empty gate disorganized mess', 'negative']
# ['southwestair aww thanks love', 'positive']
# ['usairways make thx', 'positive']
# ['guy go start fly paris virginamerica lizautter welcome', 'neutral']
# ['fuck united shitty fuck information http', 'negative']
# ['usairways americanair day amp still luggage chkd http asgmnt driver since yest', 'negative']
# ['americanair mattthomasnews american airlines start fly siberia wait usa oy', 'neutral']
# ['southwestair delay flight bdl mco need get florida amp race daytona', 'negative']
# ['united nope case id either time', 'negative']
# ['jetblue remember date monday night back nyc heartbroken', 'neutral']
# ['united people status get buy upgd much less cost ahead premier earn confirm certificate', 'negative']
# ['southwestair strives centric everything communication advertising customer journey etc anamarketers', 'negative']
# ['jetblue ceo battle appease passenger wall street waterbury republican american http', 'neutral']
# ['united hey awesome thanks reply fill form americanair', 'positive']
# ['virginamerica start flight dallas dallaslovefield austin avgeek', 'neutral']
# ['jetblue make stay jfk late flightr let rebook without make pay', 'negative']
# ['southwestair employee bwi amaze', 'positive']
# ['southwestair spare ticket vegas would forever grateful destinationdragons', 'neutral']
# ['southwestair hour airport ca move bag one plane another furious', 'negative']
# ['southwestair trouble reflight booking problems cancelled flighted flight one pick phone site work', 'negative']
# ['southwestair make world well place visit elderly relative', 'positive']
# ['jetblue bad fly experience ever suffer appreciate money back', 'negative']
# ['americanair pick best picture want board airline know', 'positive']
# ['usairways one clt know runway issue inbound flight one delayed connection left without stuck', 'negative']
# ['usairways thanks reply hop everything clear charlotte monday', 'positive']
# ['jetblue jetblue sofly wish firststari seetonight http', 'neutral']
# ['southwestair wifi plane get ta pay help broke homegirl', 'negative']
# ['americanair key point confusion whether make change even though initial flight booking problems us airways metal', 'negative']
# ['virginamerica elevategold good reason rock', 'positive']
# ['americanair hop contact wks ago respond still issue us fund frustrate', 'negative']
# ['southwestair arkansas gov plan sign governor legalizes discrimination lend voice state boycott', 'negative']
# ['united ca website put u lufthansa flight first leg', 'negative']
# ['usairways customer service fine', 'negative']
# ['americanair thank aa always start vacation http', 'positive']
# ['usairways move seat bought month ago happens far often', 'negative']
# ['united lisa j amaze guy much', 'positive']
# ['americanair sense charge bag service service great losing luggage miss item b', 'negative']
# ['usairways waive fee time cancelled flightation waive future date usairways ripoff poorcustomerservice', 'negative']
# ['jetblue thinking summer new nantucket service media pr http', 'neutral']
# ['usairways link lead website wo open cell phone good job shock airline fold', 'negative']
# ['usairways extreme inconvenience make ppl check bag lot overhead space left lie fault', 'negative']
# ['usairways delayed due frozentoilet medicalissue mechanicalissue dispatchissue heard letsgo', 'negative']
# ['united make feel guilty economy plus pay extra leg room', 'negative']
# ['united awesome thank much help', 'positive']
# ['southwestair great customer service come luv drop eb check help sight', 'positive']
# ['usairways bougth mc caren jfk agency delta airway delta refund money usairways doesnt accept refund', 'negative']
# ['southwestair thank confirmation maybe people flight directional dislexia', 'positive']
# ['americanair offer perk usairways asked told thenewamerican', 'negative']
# ['jetblue could get free flight vegas since', 'negative']
# ['jetblue sent email', 'neutral']
# ['nope rt jetblue fleet fleek http', 'neutral']
# ['americanair contact refund dm provide phone number', 'negative']
# ['americanair sent cheque today paid uk bank account annoy', 'negative']
# ['southwestair flt buf mco conf please also look reimburse car cancelled flight', 'negative']
# ['americanair upset select seat tuesday flight online phone terrible customer service please help', 'negative']
# ['southwestair refer friend southwest credit card point', 'neutral']
# ['united late flight crew btv last nite delayed today flt miss connection cun play hotel tonight ewr', 'negative']
# ['united ord roc fam come see sna member dad use mile', 'negative']
# ['jetblue flight delayed buffalo direct flight plane gate', 'negative']
# ['united flight number denver las vegas sunday feb cancelled flighted', 'negative']
# ['southwestair past yr earn status thru rnd trip month get option loyal', 'negative']
# ['southwestair thanks agent boarding left wallet inbound found', 'positive']
# ['southwestair congratulations', 'neutral']
# ['virginamerica loyal drive nyc pa fly virgin since cut philly flight', 'negative']
# ['southwestair feel flight http', 'neutral']
# ['jetblue poorservice poorcommunication waitingsince bag frm flight jetblue', 'negative']
# ['southwestair hold hour type ridiculous need link chart route time', 'negative']
# ['southwestair u see message past hour', 'negative']
# ['americanair dm anything', 'neutral']
# ['jetblue thanks make miss important dinner tonight hr delay min tarmac bad', 'negative']
# ['southwestair fact u see black history month months year honorable economic base like u future', 'negative']
# ['americanair cancelled flighted flight left help find hotel stay slept airport', 'negative']
# ['usairways left personal stuff hour ago went baggage told plane left call', 'negative']
# ['united contact request charity donation thankyou', 'neutral']
# ['southwestair two hour plane gate undignified behavior apology enough freedrinkcoupons', 'negative']
# ['usairways delayed flight phil stt look like miss car ferry john lodge help housing', 'negative']
# ['americanair please try call see happens understand allrepresentativesbusy nooption', 'negative']
# ['americanair aa good job overselling flight delayed minute deplane overflow passenger bag', 'negative']
# ['united get act right lose customer staff would let u take approve half empty flight', 'negative']
# ['united yes board way many time amp never show pas tarmac multiple time path rail way', 'negative']
# ['jetblue u suck sit ur negligence', 'negative']
# ['united look fare return companion flight understand additional fee necessary', 'negative']
# ['united guy complete as', 'negative']
# ['southwestair replace vitaminwater beer bravo cheers leinenkugels dosequis fattire', 'neutral']
# ['jetblue mark austin great handle bag issue thanks', 'positive']
# ['southwestair book flight phone never get confirmation email would go get', 'negative']
# ['americanair worry good one', 'positive']
# ['southwestair hour delay atl due air traffic control love miss entire day vacation unhappycustomer mytimeismoney', 'negative']
# ['jetblue spoke rep phone suggest voice concern via email u site moment ago', 'negative']
# ['united flight omaha chicago en route nyc seat partner separate please fix re', 'negative']
# ['jetblue enough stop fly jetblue', 'negative']
# ['southwestair theellenshow imaginedragons job interferes show amp concert alway treasure liveatfirefly experience', 'neutral']
# ['americanair jfk flight boston delayed min wait catering boarding flight lax wait hour wtf', 'negative']
# ['southwestair', 'neutral']
# ['get phone americanair customer service minute get issue resole guy awesome', 'positive']
# ['united worker told u call talk someone thailand', 'negative']
# ['united met customer service arrival flight thanks guy really handle storm', 'negative']
# ['americanair gabriela miami rude check make experience unpleasant customerexperience', 'negative']
# ['americanair say change ca make online', 'negative']
# ['americanair use hard earn mile give lousy service faulty seat leg damage bag customer care', 'negative']
# ['united fail uncontrollably today beyond repair beyond livid absolute disregard operation', 'negative']
# ['usairways', 'negative']
# ['southwestair thanks reply se conf love aviation southwest want fly swa day', 'positive']
# ['usairways southern hospitality luggage delivery service sav awful great deliver empty promise luggage amp wait', 'negative']
# ['united get right safety demonstration corporate funny reserve corny http', 'negative']
# ['united go thru detail flight want record repeat real person get line', 'negative']
# ['southwestair u cant get state play hunt destinationdragons ticket left even one', 'negative']
# ['americanair requiring customer fill contact information time seem design prevent limit interaction', 'negative']
# ['jetblue ready see n island weekend capture', 'neutral']
# ['americanair lpalumbo weather sun', 'neutral']
# ['usairways total bs offer pay full first class airfare told sold seat give seat others crap', 'negative']
# ['united favorite way travel thank http', 'positive']
# ['usairways americanair lax connect term term layover due delay realistic held', 'negative']
# ['southwestair finally hung hour able get flight need stuckintampa', 'negative']
# ['jetblue bag still fly free anymore', 'negative']
# ['southwestair get phishing email claim southwest forward like investigate', 'negative']
# ['usairways speciifc email character limit complaint customer complaint adopt twitter model', 'negative']
# ['usairways bad hold time crazy agent horrible accountability usairsucks', 'negative']
# ['southwestair understood frustrate buy early bird check day go sale get mid b feel ripped', 'negative']
# ['united pls hold cnx pax frm runner min hold save fam frm miscnx pls twitter watch', 'negative']
# ['americanair flight cancelled flighted time ca reach agent reschedule call', 'negative']
# ['jetblue super smooth flight land nicely do', 'neutral']
# ['usairways incorrect four people last flight night bag horriblecustomerservice', 'negative']
# ['americanair international airline experienced record profit last quarter ca staff call center', 'negative']
# ['usairways sorry realize follow', 'neutral']
# ['usairways guy please give update sit tarmac flight yet website still say time', 'negative']
# ['southwestair black history commercial really sweet well do', 'positive']
# ['usairways plans changed u call bein able park time planes w hr layover n b able make ur connection seriously', 'negative']
# ['united get stand list ase ord poor person aspen ask standby twitter', 'negative']
# ['southwestair next flight free cocktail', 'neutral']
# ['united airport first thing morning', 'neutral']
# ['usairways might go confirmation please wait form', 'negative']
# ['usairways thanks hectic everyone action represent company well imo', 'positive']
# ['united service desk gate help u find flight get u dest time flight get cancelled flightled', 'negative']
# ['jetblue closepwcs please tweet fly jetblue every time', 'negative']
# ['southwestair go court gain access delta gate love field http deltanews', 'positive']
# ['americanair look like mistake', 'neutral']
# ['usairways like call v try since yesterday one answer', 'negative']
# ['usairways thank glad home lot delay plane flight crew show frustrate', 'positive']
# ['jetblue long day arrived london morning', 'neutral']
# ['never get strip fast stoked special imaginedragons show tonight thx southwestair http', 'positive']
# ['usairways month old suffer rare form cancer customer service agent compassion disgust', 'negative']
# ['virginamerica flight love field sfo definitely cancelled flightled monday february', 'positive']
# ['usairways friend hold hour still counting', 'negative']
# ['united sent dm last week suit regard error response give please answer dm tell send suit', 'negative']
# ['usairways tweet get response email dmsc', 'negative']
# ['united nut say flight ground still albany wo plane someone compensate', 'negative']
# ['united let know week next another rt', 'negative']
# ['usairways americanair plane left agent door close early', 'negative']
# ['united start daily flight newark frankfurt replace avgeek', 'neutral']
# ['united currently standby lax hour ride palm springs long day start snowy philly', 'negative']
# ['southwestair yes know also notice offer list boarding program popular', 'neutral']
# ['usairways united say luggage hold almost hr usairways united hung http', 'negative']
# ['southwestair lukewyckoff name jane want call', 'neutral']
# ['americanair book wrong flight pe desk wait hour', 'negative']
# ['southwestair luv companion pas', 'neutral']
# ['usairways submit customer relation form await response', 'negative']
# ['southwestair update minute pilot turn longer freeze enjoy wait reload bag', 'negative']
# ['americanair plane toilet work need gas flight leave dulles go lax', 'negative']
# ['southwestair fantastic best flight service ever', 'positive']
# ['southwestair', 'neutral']
# ['americanair one staff desk queue hr', 'negative']
# ['united would describe feces sprinkle bathroom inconvenience help might find baggage lose amp return', 'negative']
# ['jetblue give u chance think fall backtodelta', 'neutral']
# ['united thnx', 'neutral']
# ['united inconvenience weather delay pilot decide waste enough time faa would let fly negligence', 'negative']
# ['southwestair left friday', 'neutral']
# ['jetblue ok thanks help', 'positive']
# ['southwestair happend flight get cancelled flighted hold hour help', 'negative']
# ['usairways wow awful customer service', 'negative']
# ['jetblue phone agent ca see flight see online ca change ticket even pay frustrate jetblue', 'negative']
# ['usairways guy nice give route jet blue southwest least treat customer properly', 'negative']
# ['usairways get hotel ur agent nothing help top sent luggage wrong flight', 'negative']
# ['southwestair minute phone give another number call still hold http', 'negative']
# ['southwestair end daily flight washington reagan ftmyers avgeek', 'neutral']
# ['virginamerica virgin america fly direct seattle nyc boston', 'neutral']
# ['virginamerica virginatlantic gma americanair help ourprincess need help usa http', 'neutral']
# ['jetblue okay new screen amp real nice amp wifi appreciate thanks god tiny lil man middle seat', 'positive']
# ['americanair stuck plane land crew unable figure', 'negative']
# ['united try different flight flight advertised bookable due partner error', 'negative']
# ['southwestair chance cancelled flighting flight nashville', 'neutral']
# ['southwestair ceo discus possibility nhl vegas arena name right http smusportmgt sportsbiz', 'neutral']
# ['americanair spent choppiest feed whiplash ever americanairlinesfail iwantmymoneyback', 'negative']
# ['jetblue would go las vegas gorgeous go every year fly guy vegas gorgeous amp much', 'negative']
# ['americanair hahaha meanwhile russia', 'neutral']
# ['united think board back plane whatstheholdup chitocle', 'negative']
# ['americanair gate attendant abq awful service ashamed terrible experience start finish', 'negative']
# ['americanair good expect ca get phone make change change online', 'negative']
# ['united missin point weather lie seats broken u claim weather get hotel classy', 'negative']
# ['southwestair never choose usairways getmeoffthisbird', 'negative']
# ['usairways delayed three time finally board wait minute told plan completely power', 'negative']
# ['usairways traveloneworld utterly frustrate hour hold call disconnect need amend flight booking problems help ow emerald', 'negative']
# ['usairways tweet day get live cust rep make sure world know care customer health', 'negative']
# ['southwestair make dream come true destinationdragons scavenger hunt win chance see imagine dragons go', 'neutral']
# ['southwestair would want last time screw early boarding paid', 'negative']
# ['southwestair every single flight portcolumbuscmh cancelled flightled airline', 'negative']
# ['united plane sound like dj scratch normal eventually new entertainment fee', 'negative']
# ['united hate get bumped seat select amp empty row move another seat nonupgrade', 'negative']
# ['usairways get able switch flight charge thank', 'positive']
# ['americanair least explanation one told flight cancelled flightled', 'negative']
# ['usairways thanks hope get destination', 'positive']
# ['usairways get rebooked sent wrong gate traveled back correct flight tire amp frustrate', 'negative']
# ['americanair cancelled flightled flight fresno rebooked lax flight cancelled flightled midnight hotel available', 'negative']
# ['southwestair go scavenger hunt boston', 'neutral']
# ['americanair got bag morning thanks', 'positive']
# ['united lost bag cancelled flightled flight delhi call center poor united staff spread thin stress name', 'negative']
# ['americanair edplotts bother try get anywhere customer service team either take month counting reply', 'negative']
# ['jetblue landing usual great flight wiyh great crew hello sunny west palm beach jetbluerocks', 'positive']
# ['americanair im still hold', 'negative']
# ['shit get ta stop rt jetblue fleet fleek http', 'negative']
# ['usairways yes works firefox everything finish purchase button turn gray never submits couple week', 'negative']
# ['usairways flight air plane mechanical issue wait minute help customer service help management', 'negative']
# ['united thanks gate agent extraordinaire seau fong help get boise hopefully home nyc sometime tonight', 'positive']
# ['virginamerica look forward first flight today cancelled flightled along subsequent one', 'negative']
# ['southwestair arrival delayed nearly yeah entire day airport idea stress less vacation fail', 'negative']
# ['southwestair please help really want fly guessweflyingdelta', 'neutral']
# ['jetblue employee charles cave gate msy go beyond help try help find glass thought u know', 'negative']
# ['virginamerica thanks free birthday point right', 'positive']
# ['united guy suck delay flight ca hold connector minute worstairlineever', 'negative']
# ['united surprised go last year nothing year happen soft land policy level', 'negative']
# ['united time call need ski go airport get faith united', 'negative']
# ['usairways try change flight airline travel advisory hold min help', 'negative']
# ['southwestair wifi anger slowness', 'neutral']
# ['americanair pls tell get person phone asap', 'negative']
# ['united instead bourbon street quiet plane savethediagonals', 'negative']
# ['jetblue jetbluebos luggage flt pax wait min bag show carousel sign update', 'negative']
# ['usairways number lisa liza raleigh helpful', 'negative']
# ['americanair say dumb thing beat around bush flight cancelled flightled prepared compassion', 'negative']
# ['jetblue aircanada take fraud seriously', 'negative']
# ['americanair itunesmusic put bad mood angry since spagnuolo coached rams', 'negative']
# ['united yes keep get robotic answer', 'negative']
# ['united inbound flight dep time get closer push back min hr', 'negative']
# ['united get clue miler response give', 'negative']
# ['virginamerica normal receive reply central baggage baggageissues smh', 'negative']
# ['jetblue bag hv post board carsl switch carsl comedic watch passenger run frm othr', 'negative']
# ['united asap mean two hour worth delay return terminal count luggage third time gottogetbetter', 'negative']
# ['americanair guy kill http', 'negative']
# ['united hop miss lax ito connection look forward stuck lax overnight team', 'negative']
# ['jetblue mint crew flight lax mintalicious truebluelove shelleyandmarcrock travel air', 'neutral']
# ['united help weight issue take voucher hopped delta flight instead winwin', 'negative']
# ['southwestair rule', 'neutral']
# ['united rtb gt iah first class wife global services headache due neighbor smoking e cigarette contact pls', 'negative']
# ['southwestair please please please choose go see imaginedragons destinationdragons', 'neutral']
# ['jetblue thank love anxious flyer', 'positive']
# ['united refund request functionality http get time error', 'negative']
# ['united chicago hometown airline care neighbor savethediagonals flyquiet ordnoise', 'negative']
# ['united mechanical issue cause delay connect plane ord need wait min refused left early instead wtf', 'negative']
# ['southwestair flight hrl limited route', 'neutral']
# ['united credit last trip never come mail', 'negative']
# ['americanair order always flight delayed hour bad ever forgot meal', 'negative']
# ['americanair long mait repair wait gate capt said paperwork formality force check bag cc reader work', 'negative']
# ['united pay hotel room cleveland last minute cancelled flightled connect flight booked united unimpressed', 'negative']
# ['jetblue walked hall carousel found bag sit still word crew signage still update', 'negative']
# ['united hours phone hung want different flight day open seat greatservice', 'negative']
# ['usairways americanair chairman class flight today system cancelled flightled ticket kick', 'negative']
# ['united wonderful bag claim people finally bag catch earlier flight original flight land wastedtime', 'negative']
# ['southwestair take age one snapchat story load one one demolish', 'negative']
# ['usairways msscottwg unusual mean screw never admit goingforgreatnessfail', 'negative']
# ['americanair thank respond quickly tweet appreciate', 'positive']
# ['americanair record number bpdfpp', 'neutral']
# ['usairways nothing usair cc point email state would charge thanks reply', 'negative']
# ['united time less important strandusindenver hourandtenminutedelay flightfail', 'negative']
# ['southwestair answer right away new re ca rebook people suppose leave today worst customer service', 'negative']
# ['americanair lack american air chance', 'neutral']
# ['usairways contact people still answer keep send expedia keep send', 'negative']
# ['southwestair thanks add straight flight columbus oakland', 'positive']
# ['virginamerica access website safari iphone seems work mac ipad need iphone add passbook', 'negative']
# ['usairways something wrong phone system call someone play record flight notification late flight', 'negative']
# ['united hey many time change ua go tonight mia ewr', 'negative']
# ['united think guy half full flight held overbooked flight fill one cancelled flightled mine', 'negative']
# ['americanair hi name email aadvantage website wo let reset password troubleshoot together thanks', 'negative']
# ['united pay person portland airport fly perth do us air', 'negative']
# ['southwestair want money paid early bird refund noone seem able three different sw work', 'negative']
# ['usairways even single unreasonable human planet earth excuse treatment', 'negative']
# ['jetblue come', 'neutral']
# ['virginamerica way change main cabin main cabin select flight without pay change fee penalty', 'negative']
# ['usairways get plane wait hour half speak someone reflight booking problems', 'negative']
# ['americanair great job great service sdf weekend winter storm', 'positive']
# ['southwestair give u clever advertising bagsflyfree badpolicy allows cheatcustomers', 'neutral']
# ['united get cancelled flightled hour take', 'negative']
# ['united hour sit plane left gate yet hour actual fly left', 'negative']
# ['usairways americanair piss thousand east coast customer delay longer flight fail', 'negative']
# ['united bish', 'neutral']
# ['jetblue fleet fleek http let keep professional', 'neutral']
# ['united start flight neworleans cancun avgeek', 'neutral']
# ['americanair flts jfk cancelled flightled thx ur agent sfo im rebooked ua get name awesome twitterhug shesaidrun', 'negative']
# ['usairways jetway felt disrespectful never treat way particularly try good c', 'negative']
# ['virginamerica hour operation club sfo post online current', 'neutral']
# ['jetblue pull gate sunrise bostonlogan morning jetbluesofly jetblue airbus http', 'neutral']
# ['americanair real life aa like real life people inconvenienced', 'negative']
# ['americanair try head funeral cincinnati people even tell u could get standby', 'negative']
# ['southwestair please let nothing overhead bin exit first fly lot bring purse tired run connection', 'negative']
# ['jetblue cool gate turn flight fll jax delayed yet app say time good start', 'negative']
# ['united gist flight attendant told', 'negative']
# ['americanair united equally terrible go fight get complete satisfaction mistreat', 'negative']
# ['united never fly terrible service ruined entire vacation lostsuitcase noreimbursement', 'negative']
# ['united lot report system failure delay flight last week currently sit tarmac ogg hour', 'negative']
# ['usairways today usair cancelled flightled reschedule flight amp notify u except possibly home helpful since co', 'negative']
# ['usairways amp also told comp upgrade etc reflight booking problems good enough usairwaysfail', 'negative']
# ['usairways sitting runway phl last min correct weight flight system jobfail', 'negative']
# ['americanair two day try reach americanairlines customer service change flight', 'negative']
# ['united private jet would cool work try', 'negative']
# ['virginamerica add love field route http http', 'positive']
# ['usairways call left turn united answer phone instead rebooked usair flight', 'negative']
# ['southwestair fly cun tomorrow den change flight due travel advisory', 'neutral']
# ['united cause riot airplane never see anything like', 'negative']
# ['united thanks reply get well seat next leg munich would nice', 'positive']
# ['united update flight would great', 'positive']
# ['americanair sorry enough compensate either extend time cost difference alternate direct flight right', 'negative']
# ['southwestair check grader school science fair project love fly southwest airlines http', 'positive']
# ['usairways patience connect flight need guy every time travel every single time', 'negative']
# ['jetblue change flight already print boarding pas', 'neutral']
# ['united also forgot add bag probably go sit new jersey miss connection', 'negative']
# ['united nothing like support mechanic maintenance worker instead united put video timco wifi', 'negative']
# ['southwestair flight oakland sna ask take even empty sests answer', 'negative']
# ['southwestair ca find cheap flight dc st louis price go like crazy april weekend', 'negative']
# ['united told united carry back refund', 'negative']
# ['jetblue rather try resolve customer issue option offer pay cash airport write letter justifythissupport', 'negative']
# ['jetblue try make look bad website say due weather charleston nc actually sc nc', 'negative']
# ['americanair thank', 'positive']
# ['americanair hour phone yesterday really still pick status us air flight', 'negative']
# ['southwestair baggage track system', 'negative']
# ['united usually issue express sfo positive note mainline enjoyable', 'negative']
# ['southwestair costumer service representative lie ensure plane would leave schedule', 'negative']
# ['usairways thanks betty work gate ilm lovely gate agent clt help get home phx tonight instead tomorrow', 'negative']
# ['usairways please hold see ca get first plane quick enough', 'negative']
# ['americanair bad airline cancelled flight flight even let u know even though travel child', 'negative']
# ['usairways want sit plane dca lga hour half longer flight', 'negative']
# ['americanair adress send ceo doug parker letter hopefully read', 'neutral']
# ['jetblue internal bleed foot fly next tuesday leeds come randomly', 'neutral']
# ['united whats ua lax newark', 'neutral']
# ['southwestair email address send thought experience really good amp feedback', 'negative']
# ['jetblue oh hell wait get hung speak rudeservice people', 'negative']
# ['usairways happy start trip cancelled flightled flight poor customerservice', 'negative']
# ['united please send formally compliment irene slc best customer service ever paxex', 'negative']
# ['usairways think stay w airline amp reschedule flight absorb fee cost flight', 'negative']
# ['americanair delta virginatlantic need vacation ice http', 'neutral']
# ['united unitedairlines pm ord abq ca even take walk without miss change', 'negative']
# ['americanair thanks', 'positive']
# ['americanair thanks always airline choice possible', 'positive']
# ['united since cancelled flightled flight twice', 'negative']
# ['usairways waste another hour life hold insanity another way use voucher payment online', 'negative']
# ['united know flight detail bc need explore option unable bc site wo let ongoing', 'negative']
# ['united counter agent rdu deserve medal thankyou', 'negative']
# ['southwestair route flight mexico city chicago midway use service', 'neutral']
# ['southwestair hr hang oh understand thing get crazy n sometimes hour long enough', 'negative']
# ['happy sfo hopefully add pdx soon jetblue add two new destination fll sfo las vegas last year', 'negative']
# ['jetblue love guy know paid prem wifi toplay vainglorygame go ping terrible http', 'positive']
# ['americanair flight way', 'neutral']
# ['usairways thank refund baggage really appreciate', 'positive']
# ['usairways never life dealt poor customer service irresponsible staff lack care day baggage nc', 'negative']
# ['lol great answer americanair jayfranceschi agent check passenger quickly possible appreciate patience', 'positive']
# ['usairways never worse experience life http', 'negative']
# ['usairways wait min far luggage wannagohome', 'negative']
# ['usairways thanks idea resolve like purchase ticket', 'positive']
# ['usairways flight cancelled flightled ca reach anyone phone ticket agent safe assume rebooked', 'negative']
# ['sarahpompei bother waste time usairways send u form letter amp let u choose gift certificate worstcustomerservice', 'negative']
# ['southwestair many ticket left', 'neutral']
# ['southwestair seriously reason cancelled flightled flight long phone wait time guy tremendously understaffed', 'negative']
# ['southwestair stuck heat blasting try thaw water line kinda disappointed first flight rr member', 'negative']
# ['united could access seat map say would note upgrade itinerary call back late flightr', 'negative']
# ['united flight almost half hour tarmac wait paper miss connection iah', 'negative']
# ['usairways return car clt skip flgjt back tonight gso clt pick clt fll told yes', 'negative']
# ['southwestair saw ppl win ticket still win', 'neutral']
# ['americanair yes thanks', 'positive']
# ['americanair still talk anyone guy prepared situation good service mad', 'negative']
# ['jetblue case make jackass allow favor say get right care less vacation true see peter scott', 'negative']
# ['jetblue want jetblue want jetblue', 'negative']
# ['virginamerica use passbook still love though lt use email future', 'negative']
# ['southwestair sit baltimore finish taxi approve takeoff oops enough fuel fail', 'negative']
# ['united sato rebooked upset travel office fix could', 'negative']
# ['usairways last time use airline promise', 'negative']
# ['americanair justynmoro totally agree get automatic phone attendent go hang lousy service', 'negative']
# ['united yes send email customer service today', 'negative']
# ['americanair hold service line minute phone agent min call droped', 'negative']
# ['usairways bought ticket month ago seat together change flight kid seat scatter plane', 'negative']
# ['virginamerica try book ticket nyc face super fun broken style worry keep try', 'negative']
# ['americanair get back eventually rollercoaster get airport amp get speak someone thing get fix quick', 'positive']
# ['americanair think though literally identical itinerary sample itinerary would work maybe need update', 'negative']
# ['southwestair traveling year old thursday need id correct', 'neutral']
# ['americanair rude hire requirement key west airport shake head', 'negative']
# ['united funny flight yesterday delayed mechanical issue rotten luck get plane row issue', 'negative']
# ['jetblue find flight ny schedule leave delayed check huge fail', 'negative']
# ['usairways wow unbelievable treat customer puerto rico airport', 'negative']
# ['jetblue happen mother onboard amp crew evasive return bos first time', 'negative']
# ['usairways rebooked cancelled flighting flight crew expire boarding unacceptable start delay', 'negative']
# ['united cost change city origin flight http cost customerservicefail', 'negative']
# ['jetblue flight den jfk already delayed idea might change due weather forecast etc', 'negative']
# ['united flight nightmare poor customer service confirm seat give away issue', 'negative']
# ['usairways spoke rep nh pa poor communication bags still sit philly train staff', 'negative']
# ['usairways twitter reservation connect people want reservations duh', 'negative']
# ['jetblue app remind fly fll week chillycvz thankgoodness mypompanobeach family friend sunshine', 'neutral']
# ['lololololol jetblue fleet fleek http', 'neutral']
# ['americanair bos', 'neutral']
# ['jetblue go blue go back', 'neutral']
# ['southwestair yep certain flight', 'neutral']
# ['usairways ya need work online checkout system two bank transaction one ticket bush league yell devs', 'negative']
# ['southwestair flight cancelled flightled monday look cancelled flight credit card', 'negative']
# ['virginamerica rang wait minute book ticket vendor fix site', 'negative']
# ['united flight dfw iad cancelled flightled mechanical get rental car origin', 'negative']
# ['usairways thanks ruiningmy vacation best could do without', 'positive']
# ['americanair sure bird warmer weather soon', 'neutral']
# ['jetblue great experience flight sfo jfk seat service food everything top quality back soon', 'positive']
# ['united try one available bogota everyone rude houston stuck hour guy', 'negative']
# ['usairways credit card statement receive anything way look', 'negative']
# ['united get gate iah time give seat close flight know people arrive wait', 'negative']
# ['southwestair sure hope able get bag memphis nice clean clothes work', 'negative']
# ['usairways understood u airway getting tsa problem', 'negative']
# ['united try strand u houston tomorrow morning pretty sure overflight booking problems maintenance fault', 'negative']
# ['americanair hello one forgotten need luggage ba drop ball', 'negative']
# ['usairways americanair destroy life eastern gastoncounty lively little event profit', 'negative']
# ['jetblue customer service agent jorge orlando international rude disrespectful never want deal bullshit ever', 'negative']
# ['united take week cust care respond case request refund work get update', 'negative']
# ['southwestair atl rdu snow forecast raleigh even', 'neutral']
# ['united thank excited work guy', 'positive']
# ['jetblue need eta please', 'neutral']
# ['jetblue exactly leave note', 'neutral']
# ['jetblue issue online colleague get webpage available submit online form', 'negative']
# ['southwestair yes everything work great', 'positive']
# ['jetblue thought waiver change fee travel boston weekend', 'neutral']
# ['jetblue told however would work go overseas bottom line passenger feel', 'negative']
# ['united plane wait gate two hour passenger onboard cramped seat yuck', 'negative']
# ['united real dedication amp concern apology fix issue miserable issue past mo', 'negative']
# ['usairways call btv desk information exists system make easy customer access', 'negative']
# ['americanair land crew could gracious accommodate although long delay appreciate prompt response', 'negative']
# ['united talk standby tomorrow look good may stay till friday amp guaranteed', 'negative']
# ['united load balance system apparently systemwide major impact united airline flight cyberattack', 'negative']
# ['usairways cancelled flighted amp reschedule flight amp still get update amp ca find current flight account http', 'negative']
# ['jetblue well last update right direction least keep finger cross', 'negative']
# ['southwestair carrier fly way past sw cancelled flightlation alaskaair jetblue get passenger much late flightr', 'negative']
# ['southwestair discount three delay', 'negative']
# ['kudos well deserve wish rest jetblue experience today measure example', 'positive']
# ['united enjoy heathrow lounge much almost miss airnzusa flight', 'negative']
# ['virginamerica carrier less half price round trip fare stun http', 'neutral']
# ['americanair upgraded next flight', 'neutral']
# ['usairways reach hardworking mom try best', 'negative']
# ['americanair issue base weather thing control issue base negligence', 'negative']
# ['virginamerica wtf happen pdx late flight march one way sfo', 'negative']
# ['americanair add insult injury go pick real class act stick delta', 'negative']
# ['americanair understand feel cranky call aa bag tracker number heard bag locate', 'negative']
# ['usairways need destination lunchtime today one could get u flight since learn delta one', 'negative']
# ['united glad take care reschedule ua ogg cancelled flightled http', 'negative']
# ['americanair far get maybe bag come today know website say status unknown help', 'negative']
# ['united land might want check flight plane houston sound takeoff amp land http', 'negative']
# ['southwestair really get bad day go late flight leave divert sit tarmac va', 'negative']
# ['united flight go sit tarmac forever', 'negative']
# ['usairways found tix security code work tried dozen time', 'negative']
# ['southwestair great job looking forward next trip able use new feature', 'positive']
# ...
# ['usairways actually true get seat online big hassle policy totally dishonest mislead faa', 'negative']
# ['united third wheelchair broken http', 'negative']
# ['united incentive give another chance', 'neutral']
# ['usairways hot food hour flight crazy could eat phl original connection min late flight give phltolas', 'negative']
# ['southwestair get luv fallow', 'neutral']
# ['usairways hold two hours pick phoneeeee', 'negative']
# ['southwestair wife rr point transfer rr account', 'negative']
# ['united receive call back day infant car seat suppose go anywhere child', 'negative']
# ['usairways guy offering change flight dca tomorrow afternoon', 'negative']
# ['southwestair care mighty dollar', 'neutral']
# ['united jp dm message ca get dm united', 'negative']
# ['jetblue suppose vieques', 'neutral']
# ['jetblue understood watch fam head fl expedite takeoff speak conference sf', 'negative']
# ['americanair already book flight ca use amp ca change fee flight booking problems different type ticket', 'negative']
# ['americanair please follow', 'neutral']
# ['americanair aggravate baggage fee disappear gas price drop', 'negative']
# ['usairways oh great hour delay get sit plane another hour without move flight awful', 'negative']
# ['united thnx', 'neutral']
# ['usairways never treat poorly airline life military family alot fly', 'negative']
# ['united well flight yesterday major miss unfriendly premier cabin crew baggage cluster sfo', 'negative']
# ['jetblue thanks answer question', 'positive']
# ['united forgot intl flight lax go intl terminal easiest ever woo', 'negative']
# ['jetblue ask ask pilot tell name aiecraft', 'negative']
# ['united ask lot customer routinely screw know right', 'negative']
# ['usairways wo hour hold give could borrow phone longer hour', 'negative']
# ['jetblue marty george really zero clue still job nobaggagefees http', 'negative']
# ['jetblue guy need live chat', 'neutral']
# ['united ok month wait hear airline give quite bit day request terrible service', 'negative']
# ['usairways yes get ask specifically feedback give', 'negative']
# ['united dear ted care mileage plus card pay lot bye bye united', 'negative']
# ['americanair fund purchase another ticket error would cause family miss funeral', 'negative']
# ['usairways get bag e gate b gate charlotte airport pm flight late flight cause yall ride us life', 'negative']
# ['united never flight delayed hour due unbalanced load delay flylaxairport great job idiot', 'negative']
# ['jetblue thank incredible customer svc gate flight mint experience magic', 'positive']
# ['americanair get person', 'negative']
# ['usairways submit refund request flight day ago need', 'negative']
# ['jetblue wish best luck enjoy luxurious free amount leg space rn thanks', 'positive']
# ['jetblue say start look give limit nyc waldorf astoria ca find outfit', 'negative']
# ['united bummer thank quick response', 'positive']
# ['united splitting flight quadruple price', 'negative']
# ['united fair enough usually rant good know someone listen', 'negative']
# ['jetblue dc summer help local youth get ready return school math refresher course flyitforward', 'negative']
# ['usairways thanks get u ur plane awesome flight attendant make u smile difficult travel customerservice', 'positive']
# ['jetblue miraculously fix plane kudos shoe ever', 'positive']
# ['jetblue fleet fleek http', 'neutral']
# ['usairways never heard back would help chance could bump flight time closer today flight', 'negative']
# ['southwestair bunch liar cancelled flightled flight rebooked u four day late flightr', 'negative']
# ['southwestair offering u absolutely nothing trouble either blames tsa', 'negative']
# ['usairways date back nov sent back forth disgrace', 'negative']
# ['virginamerica flight home dc sunset globe backtowinter back work refresh http', 'neutral']
# ['jetblue thinking summer new nantucket service broadway world http', 'neutral']
# ['usairways yay glitchy track system bag make destination laguardia like app say', 'negative']
# ['jetblue status flight divert ric depart back lga', 'neutral']
# ['united try log told log currently available', 'negative']
# ['usairways must nice take customer service phone hook fendforyourself', 'negative']
# ['usairways deal flight dca phl board time left gate min late flight sat tarmac', 'negative']
# ['americanair right give email write', 'negative']
# ['jetblue alternatives absolutely respect loyal customer year do', 'negative']
# ['usairways flight delayed amp close door tell u would leave hour half bad bad service', 'negative']
# ['united get email say change mileageplus account confirm make change help', 'negative']
# ['united purchase ticket entitle check bag however charge extra dollar domestic transport', 'negative']
# ['united instead told board wait email tell u delay', 'negative']
# ['united msp employee try check several hundred line crazy might miss plane sure thank employee', 'negative']
# ['southwestair cool shot moon one fleet http', 'neutral']
# ['united well keep connection ord fwa board ten minute open get plane land hour late flight', 'negative']
# ['united change entire flight plan vacation alone day night early nowhere stay help', 'negative']
# ['americanair lose basket ballbag plane', 'negative']
# ['jetblue like follow jetblue', 'neutral']
# ['southwestair hey southwest wan na go see imaginedragons guy lot well jet blue', 'negative']
# ['americanair mallowfairy many time exactly call leave number call back work', 'negative']
# ['virginamerica save sanity right http', 'neutral']
# ['united need asap make today flight', 'negative']
# ['usairways thanks', 'positive']
# ['usairways epic fail clt ystrdy flightled flight staff communication amp refund unused portion tix keep classy guy', 'negative']
# ['southwestair crazy hold time today hour help', 'negative']
# ['americanair flight great fantastic cabin crew land thankyou jfk http', 'positive']
# ['southwestair bags woman say would next flight ive get nothing big wig help', 'negative']
# ['americanair kudos crew flt today specially carlton loved new keep good work aa', 'positive']
# ['united apply one travel certificate per itinerary even multiple flight', 'negative']
# ['americanair different airport way get different airport', 'negative']
# ['united reebok rockinwellness denver international airport http', 'neutral']
# ['usairways thanks subpar travel experience even yet stepitup', 'positive']
# ['americanair two coat bag france coat walk around shirt one clean pair', 'negative']
# ['americanair play ear know best buy chewey oatmeal cooky customer care folk', 'negative']
# ['southwestair flight sunday columbus denver get travel alert southwest app reschedule', 'negative']
# ['southwestair ca update flight online bc cancelled flighted twice already going hour hold', 'negative']
# ['southwestair flight today phl dal cancelled flightled min hold rebooked tomorrow flight cancelled flightled hold', 'negative']
# ['usairways customer service atrocious', 'negative']
# ['usairways hope flight delayed flight attendant come work nobackup', 'negative']
# ['americanair expect high level customer service amp flight crew give u accurate information', 'negative']
# ['americanair prob give refund since make miss flight wait talk someone hour http', 'negative']
# ['jetblue done also look like open flight vegas sunday', 'neutral']
# ['americanair robinreda stop paris embarrassment', 'negative']
# ['usairways thanks reach gold div flights change confirmation', 'negative']
# ['united right good caught mechanical failure bad blanket ok', 'negative']
# ['united put russell daiber ticket well premium eco appreciated', 'negative']
# ['united try find loaner seat new use use car seat illegal accord safety regulation', 'negative']
# ['united gt den miss connection gt yeg due delay', 'negative']
# ['jetblue quick person travel w mosaic get green tag make sense end waitin son bag anyway', 'negative']
# ['jetblue ceo battle appease passenger wall street waterbury republican american http', 'neutral']
# ['usairways would give u option get plane instead sit hour half knew gate', 'negative']
# ['southwestair love guy even comcast well phone help system simple callback system would fix problem', 'negative']
# ['americanair flight tomorrow get cancelled flightled need find alternative get dallas please help', 'negative']
# ['southwestair please dm question', 'neutral']
# ['southwestair want pick customer spiritairlines sign', 'negative']
# ['virginamerica think pay extra buck rt luggage might afford hire extra hand sfo lame', 'negative']
# ['jetblue chance one flight leave newark nj cancelled flightled tomorrow', 'negative']
# ['jetblue since strand syr without ride miss window opportunity right matter hour', 'negative']
# ['united final pls let connection leave conf http', 'negative']
# ['americanair ca get thru anyone phone', 'negative']
# ['usairways update flight', 'negative']
# ['jetblue real shit nigga north play around', 'negative']
# ['americanair good enough need provide phone number partner investigate iata thefaaonline', 'negative']
# ['southwestair luxury people flight go get spoil', 'neutral']
# ['americanair nice people world work admiral club gladys san juan e mi amiga', 'positive']
# ['united policy behind change passenger seat assignment gate', 'negative']
# ['united rebooked casleah split take different flight pilot ran hour frustrating', 'negative']
# ['shannonwoodward want keep update wear amp amp win nice like', 'negative']
# ['united hour luggage sfo wear clothes hour thank flythefriendlyskies', 'negative']
# ['united hi im fly connect time lax enough time collect bag recheck av', 'negative']
# ['americanair keep try call change reservation keep hang', 'negative']
# ['united thanks reply box mine miss one add bag', 'positive']
# ['southwestair travel one get miscommunicated', 'neutral']
# ['usairways minute nice customer service get go', 'negative']
# ['southwestair letter follow sure include rewards number twitter handle email address', 'neutral']
# ['united try check tomorrow flight website keep timing', 'negative']
# ['usairways say meal flight would airline serf food anymore update policy', 'negative']
# ['americanair fly american family severe weather excuse ca call make change computer u cant modify', 'negative']
# ['jetblue flight return gate provide information', 'negative']
# ['jetblue feel http', 'neutral']
# ['united way simple apology go long way even hollow one obvious care', 'negative']
# ['southwestair book trip cancun baggage fee need flight time option', 'negative']
# ['thanks usairways fispahani weather disruption cause crew run late flight sorry delay flight', 'negative']
# ['united happens spook much scare', 'neutral']
# ['jetblue fleet fleek http', 'neutral']
# ['usairways delayed hour longbeachairport try get phxskyharbor give u update please', 'negative']
# ['usairways offering give bag usually force passenger state shock', 'negative']
# ['americanair request call back cancelled flighted flight dfw take long reroute customer service lack', 'negative']
# ['jetblue sure work airline jetblue different', 'negative']
# ['jetblue apparently plane delayed come san juan monsoon today', 'negative']
# ['southwestair unfortunately lack status big problem company policy force buy cheapest ticket', 'negative']
# ['usairways anyone help still hold', 'negative']
# ['usairways book flight ago seat confirmed small plane arrive allow board bcs seat horrible service', 'negative']
# ['southwestair yo try make change reservation whenever select flight say unable price please help', 'negative']
# ['usairways yes pay pocket u help loose first class ticket coach want resolution comp', 'negative']
# ['united ground crew inept left truck sit tarmac gate agent get gate', 'negative']
# ['americanair worry even though talk seat assignment', 'negative']
# ['southwestair safety dos announcer flight midway mdw pittsburgh pit', 'neutral']
# ['united please update go happen passenger flt cancelled flightled', 'negative']
# ['jetblue even gotten plane yet ca afford miss flight back boston ugh', 'negative']
# ['virginamerica digging swanky pink mood light flight nyc sfo need cabaret singer think', 'neutral']
# ['americanair helpful', 'negative']
# ['usairways number cant wait lol usairsucks', 'negative']
# ['usairways get answer question holding hour get message say take call', 'negative']
# ['americanair cathaypacific cathaypacificus ca even tell country', 'negative']
# ['americanair hey name issue reservation help', 'negative']
# ['jetblue flight delayed ny problem', 'negative']
# ['usairways first available flight tuesday flight today book flt available buy online', 'negative']
# ['southwestair got help nice lady phone georgia thank', 'positive']
# ['jetblue wait half hr package wrong guy http', 'negative']
# ['united sit runway newark wo let plane gate connection board minute united hate u', 'negative']
# ['americanair could get gate crew help u flt would great', 'positive']
# ['usairways guy luggage san jose suppose deliver hotel hour ago please contact', 'negative']
# ['southwestair luckily people work bso chicago midway attentive found bag punta cana', 'negative']
# ['usairways hr counting today alone like thing accomplish today keep hold', 'negative']
# ['americanair almost hour heard nothing yet reservation team suppose', 'negative']
# ['virginamerica thank easy itinerary shift impend weather quick painless amp free', 'positive']
# ['americanair take care cowboycerrone please thanks', 'positive']
# ['jetblue inconvenience understatement like torture clearly go wrong path jetblue', 'negative']
# ['usairways prepared weather want find take train phl catch connection', 'negative']
# ['usairways nope yet', 'negative']
# ['southwestair far good http', 'positive']
# ['southwestair cbssoxfan get hold call twice kick phonedied alistpreferred http', 'negative']
# ['jetblue really good hear thanks update may make business meeting', 'positive']
# ['jetblue try charge u dollar cash ticket paid month advance isthisreal nevertoldus jetblue neveragain', 'negative']
# ['usairways u tell clt jan gotten gate yet tight connection clt mco', 'negative']
# ['usairways customer service terrible dozens wait bag place flight staff anywhere neveragain', 'negative']
# ['southwestair whoa thanks want hear early flight come thanks reply', 'positive']
# ['united thank u secured room night thx helpful customer service rep dorns thanked u goodenoughmother', 'positive']
# ['americanair sure happen usairways status merger take place', 'negative']
# ['americanair pretty bad dfw update two flight behind door open breeze america airline worker http', 'negative']
# ['usairways contaced eyewitness news ripoff cancelled flighted want pay', 'negative']
# ['southwestair thx make right help meagan fouty brancato fl dfw gate preboard group please please', 'negative']
# ['usairways cancelled flight flight love another flight forgot bag', 'negative']
# ['united airserv contractor worth wet damn late flight still do w bag make checkin calamity', 'negative']
# ['southwestair taylormdowns share value common', 'neutral']
# ['usairways hold hr one phone hung x another reach person weather condition make excusable', 'negative']
# ['americanair flight try change hour try reach agent unbelievable', 'negative']
# ['jetblue fact chrishasmadeusblush trend know loyal', 'neutral']
# ['united somebody say flight upgrade', 'negative']
# ['southwestair get companion pas', 'neutral']
# ['usairways tell talk americanair delayed flight aa tell talk us ihatemergers', 'negative']
# ['jetblue want talk wall', 'neutral']
# ['usairways jfk baggage office actually run paper hotel voucher thislinehasntmovedforanhour', 'negative']
# ['americanair least could would refund ticket buy since able accommodate thank', 'negative']
# ['usairways stuck minute due lavatory issue beverage snack customer service flt pho fail refund', 'negative']
# ['usairways hour hour four hours like joke', 'negative']
# ['nice rt virginamerica man steel might faster wifi say sciencebehindtheexperience http', 'negative']
# ['americanair aww thanks aa dfw gma understand btw airline im able trv love guy', 'positive']
# ['united lounge tell u pillow grandma one lady open closet see right unitedlies', 'negative']
